# %%
import pandas as pd

df = pd.read_json('../data/match_results.json')
print(df.dtypes)
# Out:
# city                       object
# dates                      object
# gender                     object
# match_type                 object
# outcome.runs              float64
# outcome.winner             object
# overs                       int64
# player_of_match            object
# teams                      object
# toss.decision              object
# toss.winner                object
# umpires                    object
# venue                      object
# matchid                     int64
# outcome.wickets           float64
# result                     object
# outcome.method             object
# neutral_venue             float64
# match_type_number         float64
# outcome.result             object
# outcome.eliminator         object
# supersubs.Australia        object
# supersubs.England          object
# supersubs.Africa.XI        object
# supersubs.Asia.XI          object
# Zimbabwe                   object
# supersubs.Sri.Lanka        object
# ...

# %%
print(df.shape)
for col in df.columns:
    print(col, df[col].isna().sum())
# Out:
# (0, 42)
# city 0
# dates 0
# gender 0
# match_type 0
# outcome.runs 0
# outcome.winner 0
# overs 0
# player_of_match 0
# teams 0
# toss.decision 0
# toss.winner 0
# umpires 0
# venue 0
# matchid 0
# outcome.wickets 0
# result 0
# outcome.method 0
# neutral_venue 0
# match_type_number 0
# outcome.result 0
# outcome.eliminator 0
# supersubs.Australia 0
# supersubs.England 0
# supersubs.Africa.XI 0
# supersubs.Asia.XI 0
# Zimbabwe 0
# supersubs.Sri.Lanka 0
# supersubs.Bangladesh 0
# supersubs.Zimbabwe 0
# supersubs.New.Zealand 0
# supersubs.India 0
# supersubs.ICC.World.XI 0
# ICC.World.XI 0
# Sri.Lanka 0
# supersubs.South.Africa 0
# India 0
# England 0
# supersubs.Pakistan 0
# Australia 0
# Pakistan 0
# supersubs.West.Indies 0
# Bangladesh 0
